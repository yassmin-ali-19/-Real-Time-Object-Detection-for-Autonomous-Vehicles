# %%
from ultralytics import YOLO

model = YOLO('yolo11m.pt')  

results = model.train(
    data=r"C:\Users\Raneem\Desktop\project car\Data.yaml",  
    epochs=80,
    imgsz=640,                
    batch=8,
    lr0 = 0.0005,
    optimizer='AdamW',       
    weight_decay=0.001,
    patience=15,
    cos_lr=True,              
    label_smoothing=0.1,
    augment=True,
    copy_paste=0.3,
    project=r"C:\Users\Raneem\Desktop\project_results",  
    name="finetune_balanced_v3",  
    workers=2,
    device=0,
    save=True,)
# Out:
# New https://pypi.org/project/ultralytics/8.3.218 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.30  Python-3.12.4 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO
import torch

torch.cuda.empty_cache()

model = YOLO(r"C:\Users\Raneem\Desktop\project_results\finetune_balanced_v32\weights\last.pt")

results = model.train(
    data=r"C:\Users\Raneem\Desktop\project car\Data.yaml",
    epochs=80,
    imgsz=640,
    batch=4,
    lr0=0.0005,
    optimizer='AdamW',
    weight_decay=0.001,
    patience=15,
    cos_lr=True,
    label_smoothing=0.1,
    augment=True,
    copy_paste=0.3,
    project=r"C:\Users\Raneem\Desktop\project_results",
    name="finetune_balanced_v32",
    workers=2,
    device=0,
    resume=True
)
# Out:
# WARNING  Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Raneem\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# New https://pypi.org/project/ultralytics/8.3.220 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.30  Python-3.12.4 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
# !pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ultralytics
print(ultralytics.__file__)
# Out:
# c:\Users\Raneem\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\__init__.py

# %%
from ultralytics import YOLO

model = YOLO('yolo11m.pt') 
results = model.train(
    data=r"C:\Users\Raneem\Desktop\project car\Data.yaml",
    epochs=150,
    imgsz=640,
    batch=8,
    lr0=0.0003,
    optimizer='AdamW',
    weight_decay=0.0005,
    patience=25,
    cos_lr=True,
    label_smoothing=0.05,
    augment=True,
    mosaic=0.7,
    mixup=0.2,
    copy_paste=0.1,
    project=r"C:\Users\Raneem\Desktop\project_results",
    name="finetune_balanced4",
    workers=2,
    device=0,
    save=True)
# Out:
# WARNING 'label_smoothing' is deprecated and will be removed in the future.
# Ultralytics 8.3.221  Python-3.12.4 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...
