# %% [markdown]
# <a href="https://colab.research.google.com/github/yassmin-ali-19/-Real-Time-Object-Detection-for-Autonomous-Vehicles/blob/bassant/Uploading_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ae34aa21-6779-48f1-ada2-28214feee779" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae34aa21-6779-48f1-ada2-28214feee779">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls /content
# Out:
#  drive	'kaggle (3).json'   sample_data

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/kaggle (3).json" ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d marquis03/bdd100k -p /content/drive/MyDrive/kaggle_dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/marquis03/bdd100k
# License(s): apache-2.0
# ...
# 100% 5.38G/5.38G [00:38<00:00, 179MB/s]
# 100% 5.38G/5.38G [00:38<00:00, 149MB/s]

# %%
# !unzip -l /content/drive/MyDrive/kaggle_dataset/bdd100k.zip | grep "val"
# Out:
# Streaming output truncated to the last 5000 lines.
#     36179  2023-12-15 14:28   val/images/be6feca9-888ffd4c.jpg
#     60074  2023-12-15 14:28   val/images/be724abb-9a2a625c.jpg
#     72979  2023-12-15 14:28   val/images/be731030-7593da2a.jpg
#     85104  2023-12-15 14:28   val/images/be731030-82d58159.jpg
#     68780  2023-12-15 14:28   val/images/be731030-c29affd6.jpg
#     41574  2023-12-15 14:28   val/images/be73806a-cd8633af.jpg
#     54017  2023-12-15 14:28   val/images/be769e9f-abea5fd9.jpg
#     55195  2023-12-15 14:28   val/images/be769e9f-ed37df2b.jpg
#     33993  2023-12-15 14:28   val/images/be76ea62-78b2c8f8.jpg
#     63838  2023-12-15 14:28   val/images/be776742-fe6599b2.jpg
#     61020  2023-12-15 14:28   val/images/be777044-7db298a4.jpg
#     74698  2023-12-15 14:28   val/images/be777044-db29e596.jpg
#     65574  2023-12-15 14:28   val/images/be7783b0-b44ff154.jpg
#     47335  2023-12-15 14:28   val/images/be791a81-a6b53fef.jpg
# ...

# %%
# !unzip /content/drive/MyDrive/kaggle_dataset/bdd100k.zip "train/*" -d /content/drive/MyDrive/kaggle_dataset/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/kaggle_dataset/train/images/a5beb8ec-4711955b.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/train/images/a5beb8ec-890a5ae7.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/train/images/a5bf3583-4d11dcd8.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/train/images/a5bffb27-c38a9650.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/train/images/a5c23928-7ca89884.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/train/images/a5c24b02-f2066393.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/train/images/a5c289a6-a167d2ff.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/train/images/a5c289a6-b05c49ce.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/train/images/a5c343a3-f1b89fcb.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/train/images/a5c343a3-f3fd339b.jpg
# ...

# %%
import os
path = "/content/drive/MyDrive/kaggle_dataset/train/images"
print("Number of training images:", len(os.listdir(path)))
# Out:
# Number of training images: 70000

# %%
# !unzip /content/drive/MyDrive/kaggle_dataset/bdd100k.zip "val/*" -d /content/drive/MyDrive/kaggle_dataset/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/kaggle_dataset/val/images/be6feca9-888ffd4c.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/val/images/be724abb-9a2a625c.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/val/images/be731030-7593da2a.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/val/images/be731030-82d58159.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/val/images/be731030-c29affd6.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/val/images/be73806a-cd8633af.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/val/images/be769e9f-abea5fd9.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/val/images/be769e9f-ed37df2b.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/val/images/be76ea62-78b2c8f8.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/val/images/be776742-fe6599b2.jpg
#   inflating: /content/drive/MyDrive/kaggle_dataset/val/images/be777044-7db298a4.jpg
# ...

# %%
import os
path = "/content/drive/MyDrive/kaggle_dataset/val/images"
print("Number of validation images:", len(os.listdir(path)))
# Out:
# Number of training images: 10000

# %%
# !ls /content/drive/MyDrive/kaggle_dataset
# !ls /content/drive/MyDrive/kaggle_dataset/val | head
# Out:
# bdd100k.zip  data.yaml	train  val
# annotations
# images

# %%
# !ls -l /content/drive/MyDrive/kaggle_dataset
# Out:
# total 5645679
# -rw------- 1 root root 5781166420 Dec 15  2023 bdd100k.zip
# -rw------- 1 root root        149 Oct  2 13:16 data.yaml
# drwx------ 4 root root       4096 Oct  5 07:06 train
# drwx------ 4 root root       4096 Oct  5 07:32 val

# %%
import os
val_path = os.path.abspath("/content/drive/MyDrive/kaggle_dataset/val")
print(val_path)
# Out:
# /content/drive/MyDrive/kaggle_dataset/val

# %%
# !pwd
# !ls -l /content/drive/MyDrive/kaggle_dataset
# Out:
# /content
# total 5645679
# -rw------- 1 root root 5781166420 Dec 15  2023 bdd100k.zip
# -rw------- 1 root root        149 Oct  2 13:16 data.yaml
# drwx------ 4 root root       4096 Oct  5 07:06 train
# drwx------ 4 root root       4096 Oct  5 07:32 val

# %%
# !find /content/drive/MyDrive -type d -name "val"
# Out:
# /content/drive/MyDrive/kaggle_dataset/val

# %%
# !ls -l /content/drive/MyDrive/kaggle_dataset
# Out:
# total 5645679
# -rw------- 1 root root 5781166420 Dec 15  2023 bdd100k.zip
# -rw------- 1 root root        149 Oct  2 13:16 data.yaml
# drwx------ 4 root root       4096 Oct  5 07:06 train
# drwx------ 4 root root       4096 Oct  5 07:32 val

# %%
import os
train_path = "/content/drive/MyDrive/kaggle_dataset/train"
val_path   = "/content/drive/MyDrive/kaggle_dataset/val"
train_images = len([f for f in os.listdir(os.path.join(train_path, "images")) if f.lower().endswith(('.jpg','.png'))])
val_images   = len([f for f in os.listdir(os.path.join(val_path, "images")) if f.lower().endswith(('.jpg','.png'))])

print(f" train: {train_images}")
print(f" val:   {val_images}")
# Out:
#  train: 70000
#  val:   10000
