# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = "/content/drive/MyDrive/yolo_results"

# List all files and directories in that path
all_items = os.listdir(path)
print(all_items)
# Out:
# ['pre_val_nano', 'pre_val_nano2', 'pre_val_nano3', 'pre_val_nano4', 'pre_val_nano5']

# %%
# !pip install --upgrade ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO


model = YOLO("yolo11n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
results = model("/content/drive/MyDrive/kaggle_dataset/train/images/0a0a0b1a-7c39d841.jpg")
result = results[0]
result.show()
# Out:
# image 1/1 /content/drive/MyDrive/kaggle_dataset/train/images/0a0a0b1a-7c39d841.jpg: 384x640 2 cars, 1 bus, 3 trucks, 46.8ms
# Speed: 12.8ms preprocess, 46.8ms inference, 353.2ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
print("Using device:", device)
# Out:
# Using device: cuda

# %%
import os
save_dir = '/content/drive/MyDrive/yolo_results/pre_val_nano'
results_pre = model.val(data='/content/drive/MyDrive/kaggle_dataset/dataset.yaml',split='val',
                        project='/content/drive/MyDrive/yolo_results',
                        name='pre_val_nano')
# Out:
# ...
# val: Fast image access ✅ (ping: 0.7±0.1 ms, read: 0.1±0.0 MB/s, size: 60.6 KB)
# val: Scanning /content/drive/.shortcut-targets-by-id/1eggl69fJ7ByxgGnpit66cv84pf-fQQ7m/kaggle_dataset/val/labels... 5000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5000/5000 2.6it/s 31:53
# val: New cache created: /content/drive/.shortcut-targets-by-id/1eggl69fJ7ByxgGnpit66cv84pf-fQQ7m/kaggle_dataset/val/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 313/313 5.3it/s 59.5s
#                    all       5000      92918     0.0574     0.0566     0.0418     0.0199
#                 person       1600       6670      0.503      0.375      0.374      0.179
#                bicycle       4939      51440     0.0107   3.89e-05     0.0179    0.00813
#                    car        614        777    0.00342      0.174      0.002   0.000946
#             motorcycle       1313       2086          0          0    0.00114   0.000614
# ...
